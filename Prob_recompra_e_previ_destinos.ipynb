# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from google.colab import files
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np
from datetime import timedelta

# %%
df = pd.read_csv("/content/clientes_clusterizados.csv")

# %% [markdown]
# ## Probabilidade de recompra por perfil (cluster)

# %%
# Conversão de datas: transformamos a coluna data_da_compra em datetime para calcular intervalos.
df["data_da_compra"] = pd.to_datetime(df["data_da_compra"], errors="coerce")

# %%
# Ordenação: organizamos os registros por cliente e data para facilitar o cálculo da próxima compra.
df = df.sort_values(by=["id_do_cliente", "data_da_compra"])

# %%
# proxima_data: data da próxima compra de cada cliente.
# dias_ate_proxima: diferença em dias até a próxima compra.

# %%
# Próxima compra do cliente
df["proxima_data"] = df.groupby("id_do_cliente")["data_da_compra"].shift(-1)
df["dias_ate_proxima"] = (df["proxima_data"] - df["data_da_compra"]).dt.days

# %%
# Target binário (0/1)
df["proxima_compra"] = (df["dias_ate_proxima"] <= 30).astype(int)

# %%
# Probabilidade por cluster: calculamos a taxa média de recompra em 30 dias para cada perfil de cliente.
perfil_prob = (
    df.groupby("cluster_nome")["proxima_compra"]
      .mean()
      .reset_index()
      .rename(columns={"proxima_compra":"prob_30d"})
)

# %%
# Criar dict para mapear
mapa_prob = dict(zip(perfil_prob["cluster_nome"], perfil_prob["prob_30d"]))

# %%
# Criar coluna no dataset original
df["prob_30d_perfil"] = df["cluster_nome"].map(mapa_prob)
df["prob_30d_perfil_fmt"] = (df["prob_30d_perfil"].fillna(0)*100).round(0).astype(int).astype(str) + "%"

# %%
df
# Out:
#                 id_da_compra     id_do_cliente data_da_compra hora_da_compra  \
# 0              localizador_1      passageiro_1     2018-12-26       15:33:35
# 14369      localizador_14370      passageiro_1     2023-07-06       06:16:58
# 9308        localizador_9309      passageiro_1     2023-07-29       11:53:08
# 801440    localizador_801441      passageiro_1     2023-09-19       13:41:40
# 18540      localizador_18541      passageiro_1     2024-02-04       18:09:33
# ...                      ...               ...            ...            ...
# 1713233  localizador_1713234  passageiro_99996     2022-09-17       11:47:33
# 1735184  localizador_1735185  passageiro_99996     2023-09-30       20:07:50
# 195588    localizador_195589  passageiro_99997     2021-10-12       15:20:32
# 195590    localizador_195591  passageiro_99998     2023-03-19       09:57:45
# 195593    localizador_195594  passageiro_99999     2017-08-27       08:35:33
#
#          origem_ida destino_ida origem_retorno destino_retorno  viacao_ida  \
# 0           lugar_1     lugar_2    sem retorno     sem retorno    viacao_1
# 14369      lugar_28   lugar_111    sem retorno     sem retorno  viacao_184
# 9308       lugar_28   lugar_111    sem retorno     sem retorno  viacao_184
# 801440    lugar_111   lugar_234      lugar_234       lugar_111   viacao_19
# 18540    lugar_1236     lugar_1    sem retorno     sem retorno   viacao_10
# ...             ...         ...            ...             ...         ...
# 1713233   lugar_104    lugar_34    sem retorno     sem retorno   viacao_13
# 1735184    lugar_45    lugar_12    sem retorno     sem retorno    viacao_8
# 195588     lugar_34     lugar_8    sem retorno     sem retorno   viacao_10
# 195590    lugar_256   lugar_109    sem retorno     sem retorno   viacao_51
# 195593    lugar_169   lugar_291    sem retorno     sem retorno   viacao_15
#
#         viacao_retorno  ...  quantidade_passagens  dia_semana  feriado_fds  \
# 0          Sem retorno  ...                     1           2            0
# 14369      Sem retorno  ...                     1           3            0
# 9308       Sem retorno  ...                     1           5            1
# 801440       viacao_19  ...                     2           1            0
# 18540      Sem retorno  ...                     1           6            1
# ...                ...  ...                   ...         ...          ...
# 1713233    Sem retorno  ...                     2           5            1
# 1735184    Sem retorno  ...                     1           5            1
# 195588     Sem retorno  ...                     1           1            1
# 195590     Sem retorno  ...                     1           6            1
# 195593     Sem retorno  ...                     2           6            1
#
#          cluster_num  cluster_nome proxima_data dias_ate_proxima  \
# 0                  3     Econômico   2023-07-06           1653.0
# 14369              3     Econômico   2023-07-29             23.0
# 9308               3     Econômico   2023-09-19             52.0
# 801440             3     Econômico   2024-02-04            138.0
# 18540              3     Econômico          NaT              NaN
# ...              ...           ...          ...              ...
# 1713233            2   Fiel à rota   2023-09-30            378.0
# 1735184            2   Fiel à rota          NaT              NaN
# 195588             2   Fiel à rota          NaT              NaN
# 195590             2   Fiel à rota          NaT              NaN
# 195593             2   Fiel à rota          NaT              NaN
#
#          proxima_compra  prob_30d_perfil  prob_30d_perfil_fmt
# 0                     0         0.174603                  17%
# 14369                 1         0.174603                  17%
# 9308                  0         0.174603                  17%
# 801440                0         0.174603                  17%
# 18540                 0         0.174603                  17%
# ...                 ...              ...                  ...
# 1713233               0         0.232787                  23%
# 1735184               0         0.232787                  23%
# 195588                0         0.232787                  23%
# 195590                0         0.232787                  23%
# 195593                0         0.232787                  23%
#
# [1741344 rows x 21 columns]

# %%
# deletar as colunas: quantidade_passagens	dia_semana	feriado_fds proxima_data	dias_ate_proxima prob_30d_perfil
df = df.drop(columns=["quantidade_passagens", "dia_semana", "feriado_fds", "proxima_data", "dias_ate_proxima", "prob_30d_perfil"])

# %%
# Garantir colunas em string
df["cluster_nome"] = df["cluster_nome"].astype(str)
df["destino_ida"] = df["destino_ida"].astype(str)

# %%
# Contar quantos destinos por cluster
contagem = df.groupby(["cluster_nome", "destino_ida"]).size().reset_index(name="qtd_visitas")

# %%
# Total de destinos em cada cluster
contagem["total_cluster"] = contagem.groupby("cluster_nome")["qtd_visitas"].transform("sum")

# %%
# Calcular percentual
contagem["percentual_destino_cluster"] = (contagem["qtd_visitas"] / contagem["total_cluster"]) * 100

# %%
# Manter só as colunas úteis
contagem = contagem[["cluster_nome", "destino_ida", "percentual_destino_cluster"]]

# %%
# Juntar no dataframe
df = df.merge(contagem, on=["cluster_nome", "destino_ida"], how="left")

# %%
df
# Out:
#                 id_da_compra     id_do_cliente data_da_compra hora_da_compra  \
# 0              localizador_1      passageiro_1     2018-12-26       15:33:35
# 1          localizador_14370      passageiro_1     2023-07-06       06:16:58
# 2           localizador_9309      passageiro_1     2023-07-29       11:53:08
# 3         localizador_801441      passageiro_1     2023-09-19       13:41:40
# 4          localizador_18541      passageiro_1     2024-02-04       18:09:33
# ...                      ...               ...            ...            ...
# 1741339  localizador_1713234  passageiro_99996     2022-09-17       11:47:33
# 1741340  localizador_1735185  passageiro_99996     2023-09-30       20:07:50
# 1741341   localizador_195589  passageiro_99997     2021-10-12       15:20:32
# 1741342   localizador_195591  passageiro_99998     2023-03-19       09:57:45
# 1741343   localizador_195594  passageiro_99999     2017-08-27       08:35:33
#
#          origem_ida destino_ida origem_retorno destino_retorno  viacao_ida  \
# 0           lugar_1     lugar_2    sem retorno     sem retorno    viacao_1
# 1          lugar_28   lugar_111    sem retorno     sem retorno  viacao_184
# 2          lugar_28   lugar_111    sem retorno     sem retorno  viacao_184
# 3         lugar_111   lugar_234      lugar_234       lugar_111   viacao_19
# 4        lugar_1236     lugar_1    sem retorno     sem retorno   viacao_10
# ...             ...         ...            ...             ...         ...
# 1741339   lugar_104    lugar_34    sem retorno     sem retorno   viacao_13
# 1741340    lugar_45    lugar_12    sem retorno     sem retorno    viacao_8
# 1741341    lugar_34     lugar_8    sem retorno     sem retorno   viacao_10
# 1741342   lugar_256   lugar_109    sem retorno     sem retorno   viacao_51
# 1741343   lugar_169   lugar_291    sem retorno     sem retorno   viacao_15
#
#         viacao_retorno  valor_total  cluster_num cluster_nome  proxima_compra  \
# 0          Sem retorno        89.09            3    Econômico               0
# 1          Sem retorno       678.70            3    Econômico               1
# 2          Sem retorno       509.90            3    Econômico               0
# 3            viacao_19       823.16            3    Econômico               0
# 4          Sem retorno       181.69            3    Econômico               0
# ...                ...          ...          ...          ...             ...
# 1741339    Sem retorno       424.82            2  Fiel à rota               0
# 1741340    Sem retorno        42.18            2  Fiel à rota               0
# 1741341    Sem retorno        92.28            2  Fiel à rota               0
# 1741342    Sem retorno       120.36            2  Fiel à rota               0
# 1741343    Sem retorno       121.50            2  Fiel à rota               0
#
#         prob_30d_perfil_fmt  percentual_destino_cluster
# 0                       17%                    0.002987
# 1                       17%                    2.819931
# 2                       17%                    2.819931
# 3                       17%                    0.268849
# 4                       17%                   11.297646
# ...                     ...                         ...
# 1741339                 23%                    1.117214
# 1741340                 23%                    0.311843
# 1741341                 23%                    2.910405
# 1741342                 23%                    0.377494
# 1741343                 23%                    0.077102
#
# [1741344 rows x 16 columns]

# %%
# Garantir colunas corretas
df["cluster_nome"] = df["cluster_nome"].astype(str)
df["destino_ida"] = df["destino_ida"].astype(str)

# %% [markdown]
# ## Previsão dos destinos mais visitados por cluster

# %%
# Contamos quantas vezes cada destino_ida foi escolhido dentro de cada cluster.
# Em seguida, calculamos a porcentagem desse destino em relação ao total do cluster.
# Isso nos permite prever quais destinos são mais prováveis para cada perfil.

# %%
# Contagem por cluster e destino
contagem = df.groupby(["cluster_nome", "destino_ida"]).size().reset_index(name="qtd_visitas")

# %%
# Total por cluster
contagem["total_cluster"] = contagem.groupby("cluster_nome")["qtd_visitas"].transform("sum")

# %%
# Percentual (número normal)
contagem["percentual_destino_cluster"] = (contagem["qtd_visitas"] / contagem["total_cluster"]) * 100

# %%
# Formatar como string 1 casa decimal + %
contagem["percentual_fmt"] = contagem["percentual_destino_cluster"].map(lambda x: f"{x:.1f}%".replace(".", ","))

# %%
# Juntar no df principal
df = df.merge(contagem[["cluster_nome", "destino_ida", "percentual_fmt"]],
              on=["cluster_nome", "destino_ida"], how="left")

# %%
# Renomear coluna formatada
df = df.rename(columns={"percentual_fmt": "percentual_destino_cluster%"})

# %%
df
# Out:
#                 id_da_compra     id_do_cliente data_da_compra hora_da_compra  \
# 0              localizador_1      passageiro_1     2018-12-26       15:33:35
# 1          localizador_14370      passageiro_1     2023-07-06       06:16:58
# 2           localizador_9309      passageiro_1     2023-07-29       11:53:08
# 3         localizador_801441      passageiro_1     2023-09-19       13:41:40
# 4          localizador_18541      passageiro_1     2024-02-04       18:09:33
# ...                      ...               ...            ...            ...
# 1741339  localizador_1713234  passageiro_99996     2022-09-17       11:47:33
# 1741340  localizador_1735185  passageiro_99996     2023-09-30       20:07:50
# 1741341   localizador_195589  passageiro_99997     2021-10-12       15:20:32
# 1741342   localizador_195591  passageiro_99998     2023-03-19       09:57:45
# 1741343   localizador_195594  passageiro_99999     2017-08-27       08:35:33
#
#          origem_ida destino_ida origem_retorno destino_retorno  viacao_ida  \
# 0           lugar_1     lugar_2    sem retorno     sem retorno    viacao_1
# 1          lugar_28   lugar_111    sem retorno     sem retorno  viacao_184
# 2          lugar_28   lugar_111    sem retorno     sem retorno  viacao_184
# 3         lugar_111   lugar_234      lugar_234       lugar_111   viacao_19
# 4        lugar_1236     lugar_1    sem retorno     sem retorno   viacao_10
# ...             ...         ...            ...             ...         ...
# 1741339   lugar_104    lugar_34    sem retorno     sem retorno   viacao_13
# 1741340    lugar_45    lugar_12    sem retorno     sem retorno    viacao_8
# 1741341    lugar_34     lugar_8    sem retorno     sem retorno   viacao_10
# 1741342   lugar_256   lugar_109    sem retorno     sem retorno   viacao_51
# 1741343   lugar_169   lugar_291    sem retorno     sem retorno   viacao_15
#
#         viacao_retorno  valor_total  cluster_num cluster_nome  proxima_compra  \
# 0          Sem retorno        89.09            3    Econômico               0
# 1          Sem retorno       678.70            3    Econômico               1
# 2          Sem retorno       509.90            3    Econômico               0
# 3            viacao_19       823.16            3    Econômico               0
# 4          Sem retorno       181.69            3    Econômico               0
# ...                ...          ...          ...          ...             ...
# 1741339    Sem retorno       424.82            2  Fiel à rota               0
# 1741340    Sem retorno        42.18            2  Fiel à rota               0
# 1741341    Sem retorno        92.28            2  Fiel à rota               0
# 1741342    Sem retorno       120.36            2  Fiel à rota               0
# 1741343    Sem retorno       121.50            2  Fiel à rota               0
#
#         prob_30d_perfil_fmt  percentual_destino_cluster  \
# 0                       17%                    0.002987
# 1                       17%                    2.819931
# 2                       17%                    2.819931
# 3                       17%                    0.268849
# 4                       17%                   11.297646
# ...                     ...                         ...
# 1741339                 23%                    1.117214
# 1741340                 23%                    0.311843
# 1741341                 23%                    2.910405
# 1741342                 23%                    0.377494
# 1741343                 23%                    0.077102
#
#         percentual_destino_cluster%
# 0                              0,0%
# 1                              2,8%
# 2                              2,8%
# 3                              0,3%
# 4                             11,3%
# ...                             ...
# 1741339                        1,1%
# 1741340                        0,3%
# 1741341                        2,9%
# 1741342                        0,4%
# 1741343                        0,1%
#
# [1741344 rows x 17 columns]

# %%
# deletar coluna percentual_destino_cluster
df = df.drop(columns=["percentual_destino_cluster"])

# %%
# Uma amostra de 1000 linhas por cada cluster
df = df.groupby("cluster_nome").apply(lambda x: x.sample(n=1000, random_state=42)).reset_index(drop=True)
# Out:
# /tmp/ipython-input-3391036127.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("cluster_nome").apply(lambda x: x.sample(n=1000, random_state=42)).reset_index(drop=True)

# %%
df
# Out:
#              id_da_compra      id_do_cliente data_da_compra hora_da_compra  \
# 0     localizador_1274595  passageiro_489342     2019-11-25       14:14:30
# 1     localizador_1544394   passageiro_49930     2023-04-12       13:22:24
# 2     localizador_1728556  passageiro_131158     2022-08-08       18:47:41
# 3      localizador_953724  passageiro_402756     2022-06-22       17:16:31
# 4      localizador_642593  passageiro_287414     2022-09-06       14:49:47
# ...                   ...                ...            ...            ...
# 5995  localizador_1489663  passageiro_250354     2022-05-12       19:24:42
# 5996   localizador_907682  passageiro_271845     2023-11-19       22:52:50
# 5997   localizador_352398  passageiro_143262     2022-10-24       12:13:00
# 5998  localizador_1139716  passageiro_317258     2015-07-08       21:24:19
# 5999  localizador_1712079    passageiro_6105     2023-11-15       11:26:57
#
#      origem_ida destino_ida origem_retorno destino_retorno  viacao_ida  \
# 0      lugar_43   lugar_140    sem retorno     sem retorno    viacao_9
# 1       lugar_6    lugar_65    sem retorno     sem retorno   viacao_51
# 2     lugar_771     lugar_8    sem retorno     sem retorno   viacao_67
# 3      lugar_13   lugar_818    sem retorno     sem retorno   viacao_27
# 4     lugar_398     lugar_6    sem retorno     sem retorno   viacao_26
# ...         ...         ...            ...             ...         ...
# 5995   lugar_72    lugar_76    sem retorno     sem retorno   viacao_82
# 5996   lugar_13     lugar_1    sem retorno     sem retorno    viacao_7
# 5997   lugar_73    lugar_21    sem retorno     sem retorno    viacao_8
# 5998   lugar_13    lugar_12    sem retorno     sem retorno    viacao_8
# 5999  lugar_926    lugar_38    sem retorno     sem retorno  viacao_106
#
#      viacao_retorno  valor_total  cluster_num cluster_nome  proxima_compra  \
# 0       Sem retorno       148.78            4  Corporativo               0
# 1       Sem retorno       283.63            4  Corporativo               1
# 2       Sem retorno       222.10            4  Corporativo               0
# 3       Sem retorno       326.25            4  Corporativo               0
# 4       Sem retorno        67.83            4  Corporativo               0
# ...             ...          ...          ...          ...             ...
# 5995    Sem retorno       107.38            1      Turista               1
# 5996    Sem retorno       129.81            1      Turista               0
# 5997    Sem retorno       149.85            1      Turista               0
# 5998       viacao_8       105.79            1      Turista               1
# 5999    Sem retorno        45.95            1      Turista               1
#
#      prob_30d_perfil_fmt percentual_destino_cluster%
# 0                    21%                        0,2%
# 1                    21%                        0,1%
# 2                    21%                        1,8%
# 3                    21%                        0,0%
# 4                    21%                        8,3%
# ...                  ...                         ...
# 5995                 25%                        0,4%
# 5996                 25%                        9,7%
# 5997                 25%                        1,6%
# 5998                 25%                        0,3%
# 5999                 25%                        0,3%
#
# [6000 rows x 16 columns]

# %%
# Fazer download do arquivo
df.to_csv("Amostra_InsightBus.csv", index=False)
files.download("Amostra_InsightBus.csv")

# %%
# Fazer download do arquivo
df.to_csv("InsightBus.csv", index=False)
files.download("InsightBus.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1182234449.py in <cell line: 0>()
#       1 # Fazer download do arquivo
# ----> 2 df.to_csv("InsightBus.csv", index=False)
#       3 files.download("InsightBus.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in save(self)
#     268             )
#     269
# --> 270             self._save()
#     271
#     272     def _save(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     273         if self._need_to_save_header:
#     274             self._save_header()
# --> 275         self._save_body()
#     276
#     277     def _save_header(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     311             if start_i >= end_i:
#     312                 break
# --> 313             self._save_chunk(start_i, end_i)
#     314
#     315     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     322
#     323         ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
# --> 324         libwriters.write_csv_rows(
#     325             data,
#     326             ix,
#
# writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:
